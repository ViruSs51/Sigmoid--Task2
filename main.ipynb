# %% [markdown]
# # Task 2
# ## Task 2.1
# **Deschiderea la dataset**

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('wine-quality-white-and-red.csv')

df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# **Transferarea din string in integer**

# %%
count = df['type'].value_counts()

if 'white' in count and 'red' in count:
    df['type'] = df['type'].map({'white': 0, 'red': 1})

count
# Out:
# type
# white    4898
# red      1599
# Name: count, dtype: int64

# %% [markdown]
# *Parametrile principale a datasetului*

# %%
for axis in range(2):
    print(f'Media{axis+1}', df.mean(axis=axis), sep=' ---> ', end='\n\n')
    print(f'Mediana{axis+1}', df.median(axis=axis), sep=' ---> ', end='\n\n')
    print(f'Modul{axis+1}', df.mode(axis=axis), sep=' ---> ', end='\n\n\n')
    print(f'Std{axis+1}', df.std(axis=axis), sep=' ---> ', end='\n\n\n')

print('\n', df.describe(), sep='')
# Out:
# Media1 ---> type                      0.246114
# fixed acidity             7.215307
# volatile acidity          0.339666
# citric acid               0.318633
# residual sugar            5.443235
# chlorides                 0.056034
# free sulfur dioxide      30.525319
# total sulfur dioxide    115.744574
# density                   0.994697
# pH                        3.218501
# sulphates                 0.531268
# alcohol                  10.491801
# quality                   5.818378
# dtype: float64
#
# Mediana1 ---> type                      0.00000
# fixed acidity             7.00000
# volatile acidity          0.29000
# citric acid               0.31000
# residual sugar            3.00000
# chlorides                 0.04700
# free sulfur dioxide      29.00000
# total sulfur dioxide    118.00000
# density                   0.99489
# pH                        3.21000
# sulphates                 0.51000
# alcohol                  10.30000
# quality                   6.00000
# ...

# %% [markdown]
# **Gama de valori**

# %%
for axis in range(2):
    print(df.max(axis=axis))
    print(df.min(axis=axis))
    print(df.max(axis=axis) - df.min(axis=axis))
# Out:
# type                      1.00000
# fixed acidity            15.90000
# volatile acidity          1.58000
# citric acid               1.66000
# residual sugar           65.80000
# chlorides                 0.61100
# free sulfur dioxide     289.00000
# total sulfur dioxide    440.00000
# density                   1.03898
# pH                        4.01000
# sulphates                 2.00000
# alcohol                  14.90000
# quality                   9.00000
# dtype: float64
# type                    0.00000
# fixed acidity           3.80000
# volatile acidity        0.08000
# citric acid             0.00000
# residual sugar          0.60000
# chlorides               0.00900
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.98711
# pH                      2.72000
# sulphates               0.22000
# alcohol                 8.00000
# quality                 3.00000
# dtype: float64
# type                      1.00000
# ...

# %%
df.diff()
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      NaN            NaN               NaN          NaN             NaN
# 1      0.0           -0.7             0.030        -0.02           -19.1
# 2      0.0            1.8            -0.020         0.06             5.3
# 3      0.0           -0.9            -0.050        -0.08             1.6
# 4      0.0            0.0             0.000         0.00             0.0
# ...    ...            ...               ...          ...             ...
# 6492   0.0           -0.6            -0.020         0.00             0.1
# 6493   0.0           -0.3            -0.050         0.02             0.2
# 6494   0.0            0.4            -0.040         0.03             0.1
# 6495   0.0           -0.4             0.135        -0.01            -0.3
# 6496   0.0            0.1            -0.335         0.35             1.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ## Task 2.2
#
# **Dupa cum am citit in <a href="https://file.notion.so/f/f/afefd9da-628c-4516-b5c2-4e1eff7af20a/e63934aa-6949-4c94-a929-c349fcdade20/Sigmoid_Machine_Learning_Handbook_0_2.pdf?id=bab755b2-8c10-4268-adea-9c3dab9aa95d&table=block&spaceId=afefd9da-628c-4516-b5c2-4e1eff7af20a&expirationTimestamp=1704931200000&signature=sVJzRw-nRlIOO2i5W-YRhipfM6WcQIpyfiPD14oLW7o&downloadName=Sigmoid+Machine+Learning+Handbook_0_2.pdf">cartea precedenta</a>, valoarea la corelatie creste pentru ca valorile din matrice creste ori scade paralel, adica daca creste o valoare, creste si alta/altele. Presupun ca e asa**

# %%
def max_correlation(dataframe: pd.DataFrame, column_name: str):
    column_correlation = np.sort(dataframe.corr()[column_name].abs())
    
    return [column_correlation[-c] for c in range(1, 4)]

max_correlation(df,'pH')
# Out:
# [1.0, 0.3298081911317203, 0.32912865072599706]

# %% [markdown]
# ## Task 2.3

# %%
sigma, mu, x = 10, 2, df.values
np.multiply(np.divide(1, np.multiply(sigma, np.sqrt(np.multiply(2, np.pi)))), np.power(np.e, np.multiply(np.divide(-1, 2), np.power(np.divide(np.subtract(x, mu), sigma), 2))))
# Out:
# array([[0.03910427, 0.03520653, 0.03930168, ..., 0.03941787, 0.03165929,
#         0.03682701],
#        [0.03910427, 0.03637136, 0.0393219 , ..., 0.039442  , 0.03011374,
#         0.03682701],
#        [0.03910427, 0.03312147, 0.03930846, ..., 0.03941174, 0.02873689,
#         0.03682701],
#        ...,
#        [0.03969525, 0.03637136, 0.03945383, ..., 0.03958377, 0.02660852,
#         0.03682701],
#        [0.03969525, 0.03697277, 0.03952967, ..., 0.03956367, 0.02850364,
#         0.03813878],
#        [0.03969525, 0.03682701, 0.03932857, ..., 0.03953766, 0.02660852,
#         0.03682701]])

# %% [markdown]
# ## Task 2.4

# %%
x = df.values
np.divide(1, np.add(1, np.power(np.e, -x)))
# Out:
# array([[0.5       , 0.99908895, 0.5670929 , ..., 0.61063923, 0.99984929,
#         0.99752738],
#        [0.5       , 0.99816706, 0.57444252, ..., 0.62010643, 0.99992515,
#         0.99752738],
#        [0.5       , 0.99969655, 0.56954622, ..., 0.60825903, 0.99995892,
#         0.99752738],
#        ...,
#        [0.73105858, 0.99816706, 0.62480647, ..., 0.6791787 , 0.9999833 ,
#         0.99752738],
#        [0.73105858, 0.99726804, 0.65588284, ..., 0.67040116, 0.99996283,
#         0.99330715],
#        [0.73105858, 0.99752738, 0.57688526, ..., 0.65926039, 0.9999833 ,
#         0.99752738]])

# %% [markdown]
# ## Task 2.5

# %%
w = np.random.random(3)
y = np.random.random(6)
y_ = np.random.random(y.__len__())
X = np.random.random((y.__len__(), w.__len__()))
a = 0.0005

update_weights = lambda w, y, y_, X, a: np.subtract(w, np.multiply(a, np.mean(np.multiply(np.subtract(y_, y), X.transpose()).transpose(), axis=0)))

update_weights2 = lambda w, y, y_, X, a: np.subtract(w, np.multiply(a, np.divide(np.dot(X.transpose(), np.subtract(y_, y)), X.__len__())))

print(update_weights1(w, y, y_, X, a))
print(update_weights2(w, y, y_, X, a))
# Out:
# [0.47043122 0.71844849 0.10775867]
# [0.47043122 0.71844849 0.10775867]

# %% [markdown]
# ## Task 2.6

# %%
MSE = lambda y, y_: np.divide(np.power(np.sum(y - y_), 2), y.__len__())

MSE(y, y_)
# Out:
# 0.22316699371462936

# %% [markdown]
# ## Task 2.7

# %%
loss = lambda y, y_: np.divide(np.sum(np.add(np.multiply(y, np.log(y_)), np.multiply(np.multiply(np.subtract(1, y), np.log(np.subtract(1, y_))), 5))), y.__len__())

loss(y, y_)
# Out:
# -4.890694929633253
